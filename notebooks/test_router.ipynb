# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from backend.router_agent import classify_query

tests = [
    "Explain gradient descent",
    "What does the slide say about PCA?",
    "Summarize lecture 3",
    "How does a decision tree work?",
    "What is the kernel trick?",
]

for q in tests:
    print(q, "→", classify_query(q))
# Out:
# Explain gradient descent → general_explanation
# What does the slide say about PCA? → rag_query
# Summarize lecture 3 → rag_query
# How does a decision tree work? → general_explanation
# What is the kernel trick? → general_explanation
