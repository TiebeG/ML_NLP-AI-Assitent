# %%
# !pip install sentence-transformers chromadb langchain langchain-text-splitters
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (5.1.2)
# Requirement already satisfied: chromadb in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (1.3.5)
# Requirement already satisfied: langchain in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-text-splitters in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (1.0.0)
# Requirement already satisfied: scipy in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: scikit-learn in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: Pillow in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: tqdm in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: pydantic>=1.9 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.11.9)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: importlib-resources in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.38.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: rich>=10.11.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langchain) (1.1.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: colorama in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: pyproject_hooks in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: certifi in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.8.3)
# Requirement already satisfied: anyio in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: requests in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: filelock in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.20)
# Requirement already satisfied: durationpy>=0.7 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: requests-oauthlib in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.55)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: protobuf in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.1)
# Requirement already satisfied: coloredlogs in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: sympy in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: distro>=1.5.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: jinja2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: networkx in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: click>=8.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: pyreadline3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# STEP 2: Build Vector Database for Course Materials
import os
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
import chromadb

# ----------------------------
# Paths
# ----------------------------
TEXT_DIR = "../processed_texts"        # Output from step 1
DB_DIR = "../vectorstore"              # Chroma persistent DB

os.makedirs(DB_DIR, exist_ok=True)

# ----------------------------
# Load embedding model
# ----------------------------
print("Loading embedding model...")
embedder = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# ----------------------------
# Chunking setup
# ----------------------------
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100,
    separators=["\n\n", "\n", ".", " ", ""]
)

# ----------------------------
# Initialize Chroma DB
# ----------------------------
chroma_client = chromadb.PersistentClient(path=DB_DIR)

collection = chroma_client.get_or_create_collection(
    name="course_rag",
    metadata={"hnsw:space": "cosine"}   # cosine similarity
)

# ----------------------------
# Process each text file
# ----------------------------

total_chunks = 0

for filename in os.listdir(TEXT_DIR):
    if not filename.endswith(".txt"):
        continue

    filepath = os.path.join(TEXT_DIR, filename)
    
    print(f"\nProcessing {filename} ...")

    with open(filepath, "r", encoding="utf-8") as f:
        raw_text = f.read()

    # Split into chunks
    chunks = text_splitter.split_text(raw_text)
    print(f" → {len(chunks)} chunks created")

    # Generate embeddings
    embeddings = embedder.encode(chunks).tolist()

    # Create unique IDs for each chunk
    ids = [f"{filename}-{i}" for i in range(len(chunks))]

    # Insert into Chroma collection
    collection.add(
        ids=ids,
        embeddings=embeddings,
        documents=chunks,
        metadatas=[{"source": filename}] * len(chunks)
    )

    total_chunks += len(chunks)

print("\n-------------------------------------------")
print("✅ Vector database built successfully!")
print(f"Total chunks stored: {total_chunks}")
print(f"Saved in: {DB_DIR}")
print("-------------------------------------------")
# Out:
# Loading embedding model...
#
# Processing 1_DL_Setting_the_Scene.txt ...
#  → 13 chunks created
#
# Processing 2_DL_Adv_Deep_Learning.txt ...
#  → 18 chunks created
#
# Processing 3_DL_ComputerVision_Classification.txt ...
#  → 37 chunks created
#
# Processing 4_DL_CV_Object_Detection.txt ...
#  → 48 chunks created
#
# -------------------------------------------
# ✅ Vector database built successfully!
# Total chunks stored: 116
# Saved in: ../vectorstore
# -------------------------------------------
